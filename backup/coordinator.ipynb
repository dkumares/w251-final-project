# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import os
import time
import copy
import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
from model import CNNModel

# %%
num_trainers = 3

# %%
def touch(filename):
    open(filename, 'a').close()

# %%
def average_weights(w):
    w_avg = copy.deepcopy(w[0])
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], len(w))
    return w_avg

# %%
# Create Initial Model and send to trainer with start train instruction
global_model = CNNModel()

for i in range(1, num_trainers + 1):
    torch.save(global_model.state_dict(), 'models/global_trainer' + str(i) + '.pt')
    touch('models/start_training' + str(i))

# %%
df_test = pd.read_csv('data/mnist_test.csv')
X_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, :1]

print('Labels in this test set: ', df_test['label'].unique())
print(X_test.shape)
print(y_test.shape)
# Out:
# Labels in this test set:  [7 2 1 0 4 9 5 6 3 8]
# (10000, 784)
# (10000, 1)

# %%
X_test = np.array(X_test).reshape(X_test.shape[0], 784)

X_test = np.array(X_test.reshape(X_test.shape[0], X_test.shape[1]))
X_test = X_test.reshape(X_test.shape[0], 1, 28, 28)
X_test = torch.from_numpy(X_test).float()

y_test = np.array(y_test)
y_test = y_test.reshape(y_test.shape[0])
y_test = torch.from_numpy(np.array(y_test))
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([10000, 1, 28, 28]) torch.Size([10000])

# %%
batch_size = 100

test = torch.utils.data.TensorDataset(X_test, y_test)
test_loader = torch.utils.data.DataLoader(test, batch_size = batch_size, shuffle = False)

# %%
accuracy_list = []

total = 0
correct = 0
num_epochs = 100

max_time_to_wait = 600 #seconds

for epoch in range(num_epochs):
    
    wait_counter = 0
    timeout = False

    for i in range(1, num_trainers + 1):
        trainer_model_file = 'models/trainer' + str(i) + '_cnn.pt'
        while not os.path.exists(trainer_model_file):
            if wait_counter > max_time_to_wait:
                timeout = True
                break
            
            if wait_counter % 60 == 0:
                print('Waiting for models from trainers...')
            
            time.sleep(1)
            wait_counter = wait_counter + 1
            
    if timeout:
        # Write code to retry training. This code is not fault tolerant
        print('Placeholder to retry training.')
        break
    else:
        print('Got models from all trainers.')
    
    worker_models = []
    for i in range(1, num_trainers + 1):
        trainer_model_file = 'models/trainer' + str(i) + '_cnn.pt'
        global_model.load_state_dict(torch.load(trainer_model_file))
        worker_models.append(copy.deepcopy(global_model.state_dict()))
        
        # remove the trainer mode after loading weights
        os.remove(trainer_model_file)
        print('Loaded model: ', trainer_model_file)
        
    global_weights = average_weights(worker_models)
    
    # Load global model for evaluation
    global_model.load_state_dict(global_weights)
    global_model.eval()
    for test_images, labels in test_loader:
        # Forward propagation
        outputs = global_model(test_images)
        # Get predictions from the maximum value
        predicted = torch.max(outputs.data, 1)[1]

        # Total number of labels
        total += len(labels)
        correct += (predicted == labels).sum()

    accuracy = 100 * correct / float(total)
    
    print('Epoch: {} Accuracy: {} %'.format(epoch+1, accuracy))
    
    # Write averaged global model for trainers to train again
    if epoch < num_epochs-1:
        for i in range(1, num_trainers + 1):
            torch.save(global_model.state_dict(), 'models/global_trainer' + str(i) + '.pt')
            touch('models/start_training' + str(i))
    
    # Save global model for future
    torch.save(global_model.state_dict(), 'models/global_model.pt')
    
# Send stop signals to all trainers
for i in range(1, num_trainers + 1):
    touch('models/stop_training' + str(i))
print('Completed Training.')
# Out:
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 1 Accuracy: 25.079999923706055 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 2 Accuracy: 21.3799991607666 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 3 Accuracy: 27.850000381469727 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 4 Accuracy: 29.052499771118164 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 5 Accuracy: 34.736000061035156 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 6 Accuracy: 36.62666702270508 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 7 Accuracy: 38.08285903930664 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 8 Accuracy: 38.533748626708984 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 9 Accuracy: 41.37666702270508 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 10 Accuracy: 41.89400100708008 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 11 Accuracy: 44.10454559326172 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 12 Accuracy: 44.61166763305664 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 13 Accuracy: 46.754615783691406 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 14 Accuracy: 47.2985725402832 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 15 Accuracy: 49.20199966430664 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 16 Accuracy: 49.6875 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 17 Accuracy: 51.24588394165039 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 18 Accuracy: 51.89277648925781 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 19 Accuracy: 53.28947448730469 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 20 Accuracy: 54.140499114990234 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 21 Accuracy: 55.709049224853516 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 22 Accuracy: 56.796817779541016 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 23 Accuracy: 58.26217269897461 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 24 Accuracy: 59.35958480834961 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 25 Accuracy: 60.61600112915039 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 26 Accuracy: 61.596923828125 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 27 Accuracy: 62.641483306884766 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 28 Accuracy: 63.50107192993164 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 29 Accuracy: 64.53103637695312 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 30 Accuracy: 65.38300323486328 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 31 Accuracy: 66.25419616699219 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 32 Accuracy: 67.00062561035156 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 33 Accuracy: 67.80939483642578 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 34 Accuracy: 68.51705932617188 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 35 Accuracy: 69.27171325683594 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 36 Accuracy: 69.96444702148438 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 37 Accuracy: 70.66107940673828 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 38 Accuracy: 71.24578857421875 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 39 Accuracy: 71.8623046875 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 40 Accuracy: 72.4487533569336 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 41 Accuracy: 73.01707458496094 %
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 42 Accuracy: 73.52904510498047 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 43 Accuracy: 74.05023193359375 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 44 Accuracy: 74.48181915283203 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 45 Accuracy: 74.95622253417969 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 46 Accuracy: 75.37435150146484 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 47 Accuracy: 75.80850982666016 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 48 Accuracy: 76.15374755859375 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 49 Accuracy: 76.54142761230469 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 50 Accuracy: 76.89420318603516 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 51 Accuracy: 77.24980163574219 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 52 Accuracy: 77.59922790527344 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 53 Accuracy: 77.94415283203125 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 54 Accuracy: 78.26333618164062 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 55 Accuracy: 78.59036254882812 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 56 Accuracy: 78.90142822265625 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 57 Accuracy: 79.20806884765625 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 58 Accuracy: 79.49430847167969 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 59 Accuracy: 79.78135681152344 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 60 Accuracy: 80.00800323486328 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 61 Accuracy: 80.2637710571289 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 62 Accuracy: 80.49887084960938 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 63 Accuracy: 80.75650787353516 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 64 Accuracy: 80.9937515258789 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 65 Accuracy: 81.2270736694336 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Got models from all trainers.
# Loaded model:  models/trainer1_cnn.pt
# Loaded model:  models/trainer2_cnn.pt
# Loaded model:  models/trainer3_cnn.pt
# Epoch: 66 Accuracy: 81.43878936767578 %
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...
# Waiting for models from trainers...

# %%
# Look at the trained model
global_model.load_state_dict(torch.load('models/global_model.pt'))
# Out:
# <All keys matched successfully>

# %%
X_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, :1]

X_test = np.array(X_test).reshape(X_test.shape[0], 784)

sample = 5
img = X_test[sample] #shape (784,1)
img = img.reshape(1, 1, 28, 28) #shape (1,1,28,28)
img  = torch.from_numpy(img).float() #tensor

prediction = global_model(img).detach().numpy()[0].argmax()
print('Prediction: ', prediction)

# Look at the real picture
fig = plt.figure
plt.imshow(X_test[sample].reshape(28,28), cmap='gray')
plt.show()
# Out:
# Prediction:  1
